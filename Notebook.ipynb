# %% [markdown]
# # This is a sample heading for testing

# %% [markdown]
# Here is also some text that is subject to modification! $i \hbar \partial_t | \psi \rangle = \hat{\mathcal{H}} | \psi \rangle$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(4.5,100,1000)
y = np.sinc(x)

plt.plot(x,y)
